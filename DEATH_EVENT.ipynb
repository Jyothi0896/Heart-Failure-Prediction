# %% [markdown]
# # About this dataset
#
# Cardiovascular diseases (CVDs) are the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worlwide.
#
# Heart failure is a common event caused by CVDs and this dataset contains 12 features that can be used to predict mortality by heart failure.
#
# Most cardiovascular diseases can be prevented by addressing behavioural risk factors such as tobacco use, unhealthy diet and obesity, physical inactivity and harmful use of alcohol using population-wide strategies.
#
# People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management wherein a machine learning model can be of great help.

# %%
heart=pd.read_csv("C:/Users/sairam/Downloads/heart_failure_clinical_records_dataset.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
heart.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
heart.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
sns.pairplot(heart)

# %%
pd.crosstab(heart.age,heart.platelets).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
heart.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
heart.hist(figsize=(12,10))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'anaemia'}>,
#         <AxesSubplot:title={'center':'creatinine_phosphokinase'}>,
#         <AxesSubplot:title={'center':'diabetes'}>],
#        [<AxesSubplot:title={'center':'ejection_fraction'}>,
#         <AxesSubplot:title={'center':'high_blood_pressure'}>,
#         <AxesSubplot:title={'center':'platelets'}>,
#         <AxesSubplot:title={'center':'serum_creatinine'}>],
#        [<AxesSubplot:title={'center':'serum_sodium'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'smoking'}>,
#         <AxesSubplot:title={'center':'time'}>],
#        [<AxesSubplot:title={'center':'DEATH_EVENT'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
heart['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
heart['DEATH_EVENT'].value_counts()/len(heart)
# Out:
# 0    0.67893
# 1    0.32107
# Name: DEATH_EVENT, dtype: float64

# %%
heart.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
heart.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.101012           0.060098             0.093289
# anaemia                  -0.012729           0.031557             0.038182
# creatinine_phosphokinase -0.009639          -0.044080            -0.070590
# diabetes                  1.000000          -0.004850            -0.012732
# ejection_fraction        -0.004850           1.000000             0.024445
# high_blood_pressure      -0.012732           0.024445             1.000000
# platelets                 0.092193           0.072177             0.049963
# serum_creatinine         -0.046975          -0.011302            -0.004935
# serum_sodium             -0.089551           0.175902             0.037109
# sex                      -0.157730          -0.148386            -0.104615
# smoking                  -0.147173          -0.067315            -0.055711
# time                      0.033726           0.041729            -0.196439
# DEATH_EVENT              -0.001943          -0.268603             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052354          0.159187     -0.045966  0.065430
# anaemia                   -0.043786          0.052174      0.041882 -0.094769
# creatinine_phosphokinase   0.024463         -0.016408      0.059550  0.079791
# diabetes                   0.092193         -0.046975     -0.089551 -0.157730
# ejection_fraction          0.072177         -0.011302      0.175902 -0.148386
# high_blood_pressure        0.049963         -0.004935      0.037109 -0.104615
# platelets                  1.000000         -0.041198      0.062125 -0.125120
# serum_creatinine          -0.041198          1.000000     -0.189095  0.006970
# serum_sodium               0.062125         -0.189095      1.000000 -0.027566
# sex                       -0.125120          0.006970     -0.027566  1.000000
# smoking                    0.028234         -0.027414      0.004813  0.445892
# time                       0.010514         -0.149315      0.087640 -0.015608
# DEATH_EVENT               -0.049139          0.294278     -0.195204 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.018668 -0.224068     0.253729
# anaemia                  -0.107290 -0.141414     0.066270
# creatinine_phosphokinase  0.002421 -0.009346     0.062728
# diabetes                 -0.147173  0.033726    -0.001943
# ejection_fraction        -0.067315  0.041729    -0.268603
# high_blood_pressure      -0.055711 -0.196439     0.079351
# platelets                 0.028234  0.010514    -0.049139
# serum_creatinine         -0.027414 -0.149315     0.294278
# serum_sodium              0.004813  0.087640    -0.195204
# sex                       0.445892 -0.015608    -0.004316
# smoking                   1.000000 -0.022839    -0.012623
# time                     -0.022839  1.000000    -0.526964
# DEATH_EVENT              -0.012623 -0.526964     1.000000

# %%
heart.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
categorical=['anaemia','diabetes','high_blood_pressure','sex','smoking']
for i in categorical:
    heart[i].value_counts().plot(kind='bar',title=i)
    plt.show()

# %%
heart.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
numerical=['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time']
heart[numerical]=scaler.fit_transform(heart[numerical])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=10,test_size=0.2,random_state=18)
for train_index,test_index in split.split(heart,heart['DEATH_EVENT']):
    train_set=heart.loc[train_index]
    test_set=heart.loc[test_index]

# %%
train_set['DEATH_EVENT'].value_counts()
# Out:
# 0    162
# 1     77
# Name: DEATH_EVENT, dtype: int64

# %%
test_set['DEATH_EVENT'].value_counts()
# Out:
# 0    41
# 1    19
# Name: DEATH_EVENT, dtype: int64

# %%
train_set['DEATH_EVENT'].value_counts()/len(train_set)
# Out:
# 0    0.677824
# 1    0.322176
# Name: DEATH_EVENT, dtype: float64

# %%
test_set['DEATH_EVENT'].value_counts()/len(test_set)
# Out:
# 0    0.683333
# 1    0.316667
# Name: DEATH_EVENT, dtype: float64

# %%
from sklearn.utils import resample
train_negative=train_set[train_set['DEATH_EVENT']==0]
train_positive=train_set[train_set['DEATH_EVENT']==1]
train_positive_upsample=resample(train_positive,replace=True,n_samples=162,random_state=18)
train_upsample=pd.concat([train_negative,train_positive_upsample])
train_upsample['DEATH_EVENT'].value_counts()
# Out:
# 0    162
# 1    162
# Name: DEATH_EVENT, dtype: int64

# %%
train_upsample
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  0.400000        0                  0.004848         1           0.363636
# 211  0.181818        0                  0.071319         0           0.727273
# 122  0.363636        0                  0.009314         1           0.363636
# 204  0.690909        1                  0.005231         0           0.393939
# 274  0.363636        1                  0.029855         1           0.242424
# ..        ...      ...                       ...       ...                ...
# 32   0.181818        1                  0.028834         1           0.318182
# 187  0.363636        0                  0.238964         1           0.166667
# 65   0.363636        0                  0.005741         0           0.090909
# 140  0.727273        0                  0.099770         0           0.363636
# 44   0.363636        1                  0.072085         1           0.696970
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   0.157474          0.067416      0.857143    1
# 211                    1   0.147775          0.033708      0.771429    1
# 122                    0   0.245969          0.028090      0.771429    0
# 204                    0   0.305370          0.022472      0.685714    1
# 274                    0   0.151412          0.056180      0.685714    1
# ..                   ...        ...               ...           ...  ...
# 32                     1   0.356286          0.056180      0.428571    0
# 187                    0   0.412050          0.179775      0.885714    0
# 65                     0   0.113832          0.269663      0.400000    1
# 140                    0   0.288833          0.067416      0.600000    1
# 44                     0   0.204752          0.067416      0.828571    0
#
#      smoking      time  DEATH_EVENT
# 294        1  0.946619            0
# 211        1  0.669039            0
# 122        0  0.323843            0
# 204        1  0.651246            0
# 274        1  0.857651            0
# ..       ...       ...          ...
# 32         0  0.085409            1
# 187        0  0.597865            1
# 65         1  0.213523            1
# 140        0  0.373665            1
# 44         0  0.103203            1
#
# [324 rows x 13 columns]

# %%
x_train=train_upsample.drop('DEATH_EVENT',axis=1)
x_test=test_set.drop('DEATH_EVENT',axis=1)
y_train=train_upsample['DEATH_EVENT']
y_test=test_set['DEATH_EVENT']

# %%
x_imb=train_set.drop('DEATH_EVENT',axis=1)
y_imb=train_set['DEATH_EVENT']

# %%
def fit_classifier(model,x,y,parameters=None,scorer_metrics=None):
    grid_obj=GridSearchCV(estimator=model,param_grid=parameters,scoring=make_scorer(scorer_metrics),cv=10)
    grid_fit=grid_obj.fit(x,y)
    model_estimator=grid_fit.best_estimator_
    model_estimator.fit(x,y)
    y_pred=model_estimator.predict(x)
    
    print("\n")
    print("Model performance on training set-----------")
    print("Final accuracy score on training data: {:.4f}".format(accuracy_score(y,y_pred)))
    print("Final precision score on training data: {:.4f}".format(precision_score(y,y_pred)))
    print("Final recall score on training data: {:.4f}".format(recall_score(y,y_pred)))
    print("Final ROC score on training data: {:.4f}".format(roc_auc_score(y,y_pred)))
    print("\n")
    print("the best prameters are:{}".format(model_estimator))
    return model_estimator

# %%
def classifier_test(model_fit,x,y):
    y_pred=model_fit.predict(x)
    print('\n')
    print("Model performance on testing set-----------")
    print("Final accuracy score on testing data:{:.4f}".format(accuracy_score(y,y_pred)))
    print("Final precision score on testing data:{:.4f}".format(precision_score(y,y_pred)))
    print("Final recall score on testing data:{:.4f}".format(recall_score(y,y_pred)))
    print("Final ROC score on testing data:{:.4f}".format(roc_auc_score(y,y_pred)))
    return y_pred

# %%
from sklearn.metrics import roc_curve
def roc_curve_plot(model,x,y,label=None):
    if label=='Neural Network':
        y_score=model.predict_proba(x)[:,0]
    else:
        y_score=model.predict_proba(x)[:,1]
    roc=roc_curve(y,y_score)
    plt.plot(roc[0],roc[1],label=label)
    plt.plot([0,1],[0,1],'k--')
    plt.axis([0,1,0,1])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    roc_score=auc(roc[0],roc[1])
    print("AUC score of %s is %.4f." %(label,roc_score))

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %%
from sklearn.tree import DecisionTreeClassifier
parameters_dt={'max_depth':[6,7,8],'min_samples_split':[2,3],'min_samples_leaf':[2,3]}
model_dt=fit_classifier(DecisionTreeClassifier(random_state=18),x_train,y_train,parameters=parameters_dt,scorer_metrics=recall_score)
# Out:
# Model performance on training set-----------
# Final accuracy score on training data: 0.9846
# Final precision score on training data: 0.9816
# Final recall score on training data: 0.9877
# Final ROC score on training data: 0.9846
#
#
# the best prameters are:DecisionTreeClassifier(max_depth=8, min_samples_leaf=2, random_state=18)

# %%
y_test_dt=classifier_test(model_dt,x_test,y_test)
# Out:
# Model performance on testing set-----------
# Final accuracy score on testing data:0.8333
# Final precision score on testing data:0.8000
# Final recall score on testing data:0.6316
# Final ROC score on testing data:0.7792

# %%
import joblib

# %%
joblib.dump(model_dt,'saved_models/Decision_Tree_model.pkl')
# Out:
# ['saved_models/Decision_Tree_model.pkl']

# %%
from sklearn.linear_model import LogisticRegression
parameters_lr={'C':[0.0006,0.0007,0.0008],'penalty':['l2']}
model_lr=fit_classifier(LogisticRegression(random_state=18),x_train,y_train,parameters=parameters_lr,scorer_metrics=recall_score)
# Out:
# Model performance on training set-----------
# Final accuracy score on training data: 0.7315
# Final precision score on training data: 0.7329
# Final recall score on training data: 0.7284
# Final ROC score on training data: 0.7315
#
#
# the best prameters are:LogisticRegression(C=0.0007, random_state=18)

# %%
y_test_lr=classifier_test(model_lr,x_test,y_test)
# Out:
# Model performance on testing set-----------
# Final accuracy score on testing data:0.7333
# Final precision score on testing data:0.6000
# Final recall score on testing data:0.4737
# Final ROC score on testing data:0.6637

# %%
joblib.dump(model_lr,'saved_models/Logistic_Regression_model.pkl')
# Out:
# ['saved_models/Logistic_Regression_model.pkl']

# %%
from sklearn.ensemble import RandomForestClassifier
parameters_rf={'max_depth':[5,6,7],'min_samples_split':[2,3],'min_samples_leaf':[2,3]}
model_rf=fit_classifier(RandomForestClassifier(random_state=18),x_train,y_train,parameters=parameters_rf,scorer_metrics=recall_score)
# Out:
# Model performance on training set-----------
# Final accuracy score on training data: 0.9907
# Final precision score on training data: 0.9877
# Final recall score on training data: 0.9938
# Final ROC score on training data: 0.9907
#
#
# the best prameters are:RandomForestClassifier(max_depth=7, min_samples_leaf=2, random_state=18)

# %%
y_test_rf=classifier_test(model_rf,x_test,y_test)
# Out:
# Model performance on testing set-----------
# Final accuracy score on testing data:0.8833
# Final precision score on testing data:0.9286
# Final recall score on testing data:0.6842
# Final ROC score on testing data:0.8299

# %%
joblib.dump(model_rf,'saved_models/Random_Forest_model.pkl')
# Out:
# ['saved_models/Random_Forest_model.pkl']

# %%
model_dt=joblib.load('saved_models/Decision_Tree_model.pkl')
model_lr=joblib.load('saved_models/Logistic_Regression_model.pkl')
model_rf=joblib.load('saved_models/Random_Forest_model.pkl')

# %%
model_dt.feature_importances_
# Out:
# array([0.04542519, 0.        , 0.0513336 , 0.        , 0.09064626,
#        0.02569593, 0.07164014, 0.14178623, 0.06368634, 0.        ,
#        0.        , 0.50978632])

# %%
model_rf.feature_importances_
# Out:
# array([0.07265549, 0.01024725, 0.07220503, 0.01083077, 0.13773973,
#        0.00979595, 0.06698968, 0.1668388 , 0.07061609, 0.00782757,
#        0.00906023, 0.36519342])

# %%
from sklearn.metrics import auc

# %%
roc_curve_plot(model_dt,x_imb,y_imb,label='Decision_Tree')
roc_curve_plot(model_lr,x_imb,y_imb,label='Logistic_Regression')
roc_curve_plot(model_rf,x_imb,y_imb,label='Ranodm_Forest')
plt.title("ROC curve on imbalanced datasets")
plt.legend(loc='lower right')
# Out:
# AUC score of Decision_Tree is 0.9857.
# AUC score of Logistic_Regression is 0.8188.
# AUC score of Ranodm_Forest is 0.9986.

# %%
roc_curve_plot(model_dt,x_test,y_test,label='DecisionTree')
roc_curve_plot(model_lr,x_test,y_test,label='Logistic_Regression')
roc_curve_plot(model_rf,x_test,y_test,label='Ranodm_Forest')
plt.title("roc on testing data")
plt.legend(loc="lower right")
# Out:
# AUC score of DecisionTree is 0.7869.
# AUC score of Logistic_Regression is 0.7612.
# AUC score of Ranodm_Forest is 0.9345.

# %%
parameters_dt_imp={'max_depth':[5,6,7],'min_samples_split':[2,3],'min_samples_leaf':[2,3],'criterion':['gini','entropy'],'splitter':['best','random'],'max_features':[None,'auto','sqrt','log2'],'class_weight':[None,'balanced']}
model_dt_imp=fit_classifier(DecisionTreeClassifier(random_state=18),x_train,y_train,parameters=parameters_dt_imp,scorer_metrics=recall_score)
# Out:
# Model performance on training set-----------
# Final accuracy score on training data: 0.9722
# Final precision score on training data: 0.9581
# Final recall score on training data: 0.9877
# Final ROC score on training data: 0.9722
#
#
# the best prameters are:DecisionTreeClassifier(class_weight='balanced', max_depth=6, min_samples_leaf=2,
#                        random_state=18)

# %%
y_test_dt_imp=classifier_test(model_dt_imp,x_test,y_test)
# Out:
# Model performance on testing set-----------
# Final accuracy score on testing data:0.8333
# Final precision score on testing data:0.8000
# Final recall score on testing data:0.6316
# Final ROC score on testing data:0.7792

# %%
joblib.dump(model_dt_imp,'saved_models/Decision_Tree_imp_model.pkl')
# Out:
# ['saved_models/Decision_Tree_imp_model.pkl']

# %%
model_dt_imp=joblib.load('saved_models/Decision_Tree_imp_model.pkl')

# %%
roc_curve_plot(model_dt,x_imb,y_imb,label='Decisoin_Tree')
roc_curve_plot(model_dt_imp,x_imb,y_imb,label='DecisionTreeImprovised')
plt.title("roc curve on training")
plt.legend(loc='lower right')
# Out:
# AUC score of Decisoin_Tree is 0.9857.
# AUC score of DecisionTreeImprovised is 0.9827.

# %%
roc_curve_plot(model_rf,x_test,y_test,label='Decision_Tree')
roc_curve_plot(model_rf,x_test,y_test,label='DecisionTreeIMprovised')
plt.title("roc curve on testing")
plt.legend(loc="lower right")
# Out:
# AUC score of Decision_Tree is 0.9345.
# AUC score of DecisionTreeIMprovised is 0.9345.

# %%
joblib.dump(model_dt_imp,'saved_models/final_model.pkl')
# Out:
# ['saved_models/final_model.pkl']

# %%
x_train.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time'],
#       dtype='object')

# %%
series_feature=pd.Series(index=x_train.columns,data=model_dt.feature_importances_.reshape(,))
feature_dict={}
for i in heart.columns[:-1]:
    feature_dict[i]=0
for i in series_feature.index:
    for j in feature_dict.keys():
        if j in i:
            feature_dict[j]+=series_feature[i]
        else:
            continue
series_feature=pd.Series(feature_dict)
feature_sort=series_feature.sort_values(ascending=False)
feature_sort[0:10].plot.bar(figsize=(10,6))
plt.title("Feture importance of 10 features")
plt.xlabel("Top 10 features")
plt.ylabel("Importance contribution %")
# Out:
# Text(0, 0.5, 'Importance contribution %')

# %%
feature_dict
# Out:
# {'age': 0.045425190416007434,
#  'anaemia': 0.0,
#  'creatinine_phosphokinase': 0.05133359553671575,
#  'diabetes': 0.0,
#  'ejection_fraction': 0.09064625653310922,
#  'high_blood_pressure': 0.025695931477516067,
#  'platelets': 0.07164013762836365,
#  'serum_creatinine': 0.14178623100316418,
#  'serum_sodium': 0.06368633933155518,
#  'sex': 0.0,
#  'smoking': 0.0,
#  'time': 0.5097863180735684}
